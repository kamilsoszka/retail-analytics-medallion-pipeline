# %%
# Databricks notebook: 00_run_all_pipeline
# Runs all Medallion notebooks in sequence (01 to 05) using dbutils.notebook.run()

print("Starting Medallion pipeline...")

# Run each notebook (adjust paths if needed)
dbutils.notebook.run("./01_ingest_bronze", 0)
dbutils.notebook.run("./02_transform_silver", 0)
dbutils.notebook.run("./03_create_gold_views", 0)
dbutils.notebook.run("./04_optimize_delta", 0)
dbutils.notebook.run("./05_validate_silver_gold", 0)

print("Pipeline completed successfully.")
# Out:
# Starting Medallion pipeline...
# Pipeline completed successfully.
